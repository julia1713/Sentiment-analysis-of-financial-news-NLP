# %% [markdown]
# ## FINANCIAL NEWS COLLECTION
#
# ### FIRST DATASET
# 13867 FINANCIAL NEWS HEADLINES (+ SOME DESCRIPTIONS) RANGING FROM 1 JAN TO 9 JULY 2020

# %%
import pandas as pd

# %%
df = pd.read_csv('cnbc_headlines.csv')
df1 = pd.read_csv('guardian_headlines.csv')
df2 = pd.read_csv('reuters_headlines.csv')
df.describe()
# Out:
#                                                                                 Headlines  \
# count   2800
# unique  2788
# top     Cramer: I helped investors through the 2010 flash crash by following one key rule
# freq    2
#
#                                  Time  \
# count   2800
# unique  2474
# top      8:11  PM ET Fri,  2 Nov 2018
# freq    6
#
#                                                                                                                                         Description
# count   2800
# unique  2618
# top     "Mad Money" host Jim Cramer rings the lightning round bell, which means he's giving his answers to callers' stock questions at rapid speed.
# freq    147

# %%
df1.describe()
# Out:
#              Time  \
# count   17800
# unique  774
# top     25-Feb-20
# freq    40
#
#                                                                  Headlines
# count   17800
# unique  17795
# top     Deliveroo couriers win six-figure payout in employment rights case
# freq    2

# %%
df2.describe()
# Out:
#                                                  Headlines         Time  \
# count   32770                                               32770
# unique  32575                                               852
# top     Take Five: World markets themes for the week ahead  Mar 19 2020
# freq    12                                                  126
#
#                                                                                                                                            Description
# count   32770
# unique  32574
# top     Following are five big themes likely to dominate thinking of investors and traders in the coming week and the Reuters stories related to them.
# freq    25

# %%
df = pd.DataFrame(df)
df1 = pd.DataFrame(df1)
df2 = pd.DataFrame(df2)
df.describe()
# Out:
#                                                                                 Headlines  \
# count   2800
# unique  2788
# top     Cramer: I helped investors through the 2010 flash crash by following one key rule
# freq    2
#
#                                  Time  \
# count   2800
# unique  2474
# top      8:11  PM ET Fri,  2 Nov 2018
# freq    6
#
#                                                                                                                                         Description
# count   2800
# unique  2618
# top     "Mad Money" host Jim Cramer rings the lightning round bell, which means he's giving his answers to callers' stock questions at rapid speed.
# freq    147

# %%
df2.describe()
# Out:
#                                                  Headlines         Time  \
# count   32770                                               32770
# unique  32575                                               852
# top     Take Five: World markets themes for the week ahead  Mar 19 2020
# freq    12                                                  126
#
#                                                                                                                                            Description
# count   32770
# unique  32574
# top     Following are five big themes likely to dominate thinking of investors and traders in the coming week and the Reuters stories related to them.
# freq    25

# %%
df1.describe()
# Out:
#              Time  \
# count   17800
# unique  774
# top     25-Feb-20
# freq    40
#
#                                                                  Headlines
# count   17800
# unique  17795
# top     Deliveroo couriers win six-figure payout in employment rights case
# freq    2

# %%
df =df.dropna(how='all')
df1 =df1.dropna(how='all')
df2 =df2.dropna(how='all')

df.describe()
# Out:
#                                                                                 Headlines  \
# count   2800
# unique  2788
# top     Cramer: I helped investors through the 2010 flash crash by following one key rule
# freq    2
#
#                                  Time  \
# count   2800
# unique  2474
# top      8:11  PM ET Fri,  2 Nov 2018
# freq    6
#
#                                                                                                                                         Description
# count   2800
# unique  2618
# top     "Mad Money" host Jim Cramer rings the lightning round bell, which means he's giving his answers to callers' stock questions at rapid speed.
# freq    147

# %%
df1.describe()
# Out:
#              Time  \
# count   17800
# unique  774
# top     25-Feb-20
# freq    40
#
#                                                                  Headlines
# count   17800
# unique  17795
# top     Deliveroo couriers win six-figure payout in employment rights case
# freq    2

# %%
df2.describe()
# Out:
#                                                  Headlines         Time  \
# count   32770                                               32770
# unique  32575                                               852
# top     Take Five: World markets themes for the week ahead  Mar 19 2020
# freq    12                                                  126
#
#                                                                                                                                            Description
# count   32770
# unique  32574
# top     Following are five big themes likely to dominate thinking of investors and traders in the coming week and the Reuters stories related to them.
# freq    25

# %% [markdown]
# SELEZIONO I DATI RELATIVI AL 2020

# %%
df = df.loc[df['Time'].str.contains('2020')]
df1 = df1.loc[df1['Time'].str.contains('-20')]
df2 = df2.loc[df2['Time'].str.contains('2020')]
df
# Out:
#                                                                                            Headlines  \
# 0     Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush
# 1     Cramer's lightning round: I would own Teradyne
# 3     Cramer's week ahead: Big week for earnings, even bigger week for vaccines
# 4     IQ Capital CEO Keith Bliss says tech and healthcare will rally
# 5     Wall Street delivered the 'kind of pullback I've been waiting for,' Jim Cramer says
# ...                                                                                   ...
# 626   Everything Jim Cramer said on 'Mad Money,' including understanding Wall Street jargon
# 627   'Know what you own and know what others will pay for it,' Jim Cramer advises
# 628   Jim Cramer deciphers the Wall Street lingo behind stock valuations
# 629   Investing is about differentiating between cyclical and secular growth stocks, Jim Cramer says
# ...

# %%
type(df['Time'][0])
# Out:
# str

# %%
df['Time'][0]
# Out:
# ' 7:51  PM ET Fri, 17 July 2020'

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
type(df['Time'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df
# Out:
#                                                                                            Headlines  \
# 0     Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush
# 1     Cramer's lightning round: I would own Teradyne
# 3     Cramer's week ahead: Big week for earnings, even bigger week for vaccines
# 4     IQ Capital CEO Keith Bliss says tech and healthcare will rally
# 5     Wall Street delivered the 'kind of pullback I've been waiting for,' Jim Cramer says
# ...                                                                                   ...
# 626   Everything Jim Cramer said on 'Mad Money,' including understanding Wall Street jargon
# 627   'Know what you own and know what others will pay for it,' Jim Cramer advises
# 628   Jim Cramer deciphers the Wall Street lingo behind stock valuations
# 629   Investing is about differentiating between cyclical and secular growth stocks, Jim Cramer says
# ...

# %%
df['Date'] = df['Time'].dt.date

# %%
df
# Out:
#                                                                                            Headlines  \
# 0     Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush
# 1     Cramer's lightning round: I would own Teradyne
# 3     Cramer's week ahead: Big week for earnings, even bigger week for vaccines
# 4     IQ Capital CEO Keith Bliss says tech and healthcare will rally
# 5     Wall Street delivered the 'kind of pullback I've been waiting for,' Jim Cramer says
# ...                                                                                   ...
# 626   Everything Jim Cramer said on 'Mad Money,' including understanding Wall Street jargon
# 627   'Know what you own and know what others will pay for it,' Jim Cramer advises
# 628   Jim Cramer deciphers the Wall Street lingo behind stock valuations
# 629   Investing is about differentiating between cyclical and secular growth stocks, Jim Cramer says
# ...

# %%
df2.describe()
# Out:
#                                                                                Headlines  \
# count   9214
# unique  9163
# top     Factbox: What changes are companies making in response to George Floyd protests?
# freq    4
#
#                Time  \
# count   9214
# unique  200
# top     Mar 19 2020
# freq    126
#
#                                                                                                                                                              Description
# count   9214
# unique  9164
# top     Airlines across the globe are feeling the pain as travel demand withers because of the coronavirus outbreak, scrapping flights and ditching financial forecasts.
# freq    4

# %%
df2['Time'] = pd.to_datetime(df2['Time'])
df2
# Out:
#                                                                                      Headlines  \
# 0     TikTok considers London and other locations for headquarters
# 1     Disney cuts ad spending on Facebook amid growing boycott: WSJ
# 2     Trail of missing Wirecard executive leads to Belarus, Der Spiegel reports
# 3     Twitter says attackers downloaded data from up to eight non-verified accounts
# 4     U.S. Republicans seek liability protections as coronavirus aid battle looms
# ...                                                                           ...
# 9209  Britain's Lloyds Banking Group suffers hours-long online outage
# 9210  Surveillance in a leafy enclave, Ghosn's Tokyo life was under strict monitoring
# 9211  Ghosn flight prompts talk of more curbs in Japan's strict justice system
# 9212  Surveillance in a leafy enclave, Ghosn's Tokyo life was under strict monitoring
# ...

# %%
df2['Date'] = df2['Time'].dt.date
df2
# Out:
#                                                                                      Headlines  \
# 0     TikTok considers London and other locations for headquarters
# 1     Disney cuts ad spending on Facebook amid growing boycott: WSJ
# 2     Trail of missing Wirecard executive leads to Belarus, Der Spiegel reports
# 3     Twitter says attackers downloaded data from up to eight non-verified accounts
# 4     U.S. Republicans seek liability protections as coronavirus aid battle looms
# ...                                                                           ...
# 9209  Britain's Lloyds Banking Group suffers hours-long online outage
# 9210  Surveillance in a leafy enclave, Ghosn's Tokyo life was under strict monitoring
# 9211  Ghosn flight prompts talk of more curbs in Japan's strict justice system
# 9212  Surveillance in a leafy enclave, Ghosn's Tokyo life was under strict monitoring
# ...

# %%
df1.describe()
# Out:
#              Time  \
# count   4080
# unique  170
# top     31-Mar-20
# freq    40
#
#                                                                                     Headlines
# count   4080
# unique  4079
# top     Treasury mulls plan to set up coronavirus toxic debt body to save UK small businesses
# freq    2

# %%
df1['Time'] = pd.to_datetime(df1['Time'])
df1
# Out:
#            Time  \
# 0    2020-07-18
# 1    2020-07-18
# 2    2020-07-18
# 3    2020-07-18
# 4    2020-07-18
# ...         ...
# 4075 2020-01-02
# 4076 2020-01-02
# 4077 2020-01-02
# 4078 2020-01-02
# 4079 2020-01-02
#
#                                                                                                               Headlines
# 0     Johnson is asking Santa for a Christmas recovery
# 1     ‘I now fear the worst’: four grim tales of working life upended by Covid-19
# 2     Five key areas Sunak must tackle to serve up economic recovery
# 3     Covid-19 leaves firms ‘fatally ill-prepared’ for no-deal Brexit
# 4     The Week in Patriarchy  \n\n\n  Bacardi's 'lady vodka': the latest in a long line of depressing gendered products
# ...                                                                                                                 ...
# 4075  Carlos Ghosn's escape from Japan 'was aided by Lebanese officials'
# ...

# %%
df1['Date'] = df1['Time'].dt.date
df1
# Out:
#            Time  \
# 0    2020-07-18
# 1    2020-07-18
# 2    2020-07-18
# 3    2020-07-18
# 4    2020-07-18
# ...         ...
# 4075 2020-01-02
# 4076 2020-01-02
# 4077 2020-01-02
# 4078 2020-01-02
# 4079 2020-01-02
#
#                                                                                                               Headlines  \
# 0     Johnson is asking Santa for a Christmas recovery
# 1     ‘I now fear the worst’: four grim tales of working life upended by Covid-19
# 2     Five key areas Sunak must tackle to serve up economic recovery
# 3     Covid-19 leaves firms ‘fatally ill-prepared’ for no-deal Brexit
# 4     The Week in Patriarchy  \n\n\n  Bacardi's 'lady vodka': the latest in a long line of depressing gendered products
# ...                                                                                                                 ...
# 4075  Carlos Ghosn's escape from Japan 'was aided by Lebanese officials'
# ...

# %%
list_of_df = []
list_of_df.append(df)
list_of_df.append(df1)
list_of_df.append(df2)
merged_df = pd.concat(list_of_df)
merged_df
# Out:
#                                                                                      Headlines  \
# 0     Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush
# 1     Cramer's lightning round: I would own Teradyne
# 3     Cramer's week ahead: Big week for earnings, even bigger week for vaccines
# 4     IQ Capital CEO Keith Bliss says tech and healthcare will rally
# 5     Wall Street delivered the 'kind of pullback I've been waiting for,' Jim Cramer says
# ...                                                                                   ...
# 9209  Britain's Lloyds Banking Group suffers hours-long online outage
# 9210  Surveillance in a leafy enclave, Ghosn's Tokyo life was under strict monitoring
# 9211  Ghosn flight prompts talk of more curbs in Japan's strict justice system
# 9212  Surveillance in a leafy enclave, Ghosn's Tokyo life was under strict monitoring
# 9213  Samsung Electronics chip output at South Korea plant partly halted due to short blackout
#
# ...

# %%
#userò la data come indice
#df=df.set_index('Date')
#df1=df1.set_index('Time')
#df2=df2.set_index('Time')
#df

# %%
merged_df.to_csv('data2020.csv',index=False)

# %%
import matplotlib.pyplot as plt
months = range(1,13) #13 is escluso
results = merged_df.groupby('Date').count()
results
# Out:
#             Headlines  Time  Description
# Date
# 2020-01-01  10         10    10
# 2020-01-02  51         51    31
# 2020-01-03  53         53    33
# 2020-01-04  9          9     9
# 2020-01-05  29         29    9
# ...        ..         ..    ..
# 2020-07-14  114        114   94
# 2020-07-15  123        123   83
# 2020-07-16  117        117   97
# 2020-07-17  72         72    52
# 2020-07-18  24         24    4
#
# [200 rows x 3 columns]

# %%
plt.plot(results['Headlines'])
plt.xticks( rotation='vertical')
plt.ylabel('Number of news')
plt.xlabel('Date')
plt.figure(figsize=(14,9))

plt.show()

# %%
merged_df['Date']
# Out:
# 0       2020-07-17
# 1       2020-07-17
# 3       2020-07-17
# 4       2020-07-17
# 5       2020-07-16
#            ...
# 9209    2020-01-01
# 9210    2020-01-01
# 9211    2020-01-01
# 9212    2020-01-01
# 9213    2020-01-01
# Name: Date, Length: 13867, dtype: object

# %%
# data taken from https://www.kaggle.com/notlucasp/financial-news-headlines
# Scraped from CNBC, the Guardian, and Reuters official websites, the headlines in these datasets reflects the overview of the U.S. economy and stock market every day for the past year to 2 years.
# Data is till July 19th, 2020.

# %% [markdown]
# # SECOND DATASET HERE taken from
# ####  https://www.kaggle.com/miguelaenlle/massive-stock-news-analysis-db-for-nlpbacktests?select=raw_partner_headlines.csv
#
# rawpartnerheadlines.csv
# Directly-scraped raw news headlines
# Columns go as follows: index, headline, URL, publisher (NOT benzinga), date, stock ticker.
#
# Data till 4 june 2020

# %%
data2 = pd.read_csv('raw_partner_headlines.csv', index_col=0 )

# %%
data2 = pd.DataFrame(data2)
data2
# Out:
#                                                   headline  \
# 2        Agilent Technologies Announces Pricing of $5……...
# 3        Agilent (A) Gears Up for Q2 Earnings: What's i...
# 4        J.P. Morgan Asset Management Announces Liquida...
# 5        Pershing Square Capital Management, L.P. Buys ...
# 6        Agilent Awards Trilogy Sciences with a Golden ...
# ...                                                    ...
# 1849874                      Consumer Cyclical Sector Wrap
# 1849875                      Consumer Cyclical Sector Wrap
# 1849876  Zacks #5 Rank Additions for Monday - Tale of t...
# 1849877  4 Stock Strategies From Wall Street: Feb. 9 (U...
# 1849878        4 Stock Strategies From Wall Street: Feb. 9
#
#                                                        url      publisher  \
# 2        http://www.gurufocus.com/news/1153187/agilent-...      GuruFocus
# 3        http://www.zacks.com/stock/news/931205/agilent...          Zacks
# ...

# %%
data2.publisher.unique()
# Out:
# array(['GuruFocus', 'Zacks', "Investor's Business Daily", 'TalkMarkets',
#        'BayStreet'], dtype=object)

# %%
data2 = data2.loc[data2['date'].str.contains('2020')]
data2
# Out:
#                                                   headline  \
# 2        Agilent Technologies Announces Pricing of $5……...
# 3        Agilent (A) Gears Up for Q2 Earnings: What's i...
# 4        J.P. Morgan Asset Management Announces Liquida...
# 5        Pershing Square Capital Management, L.P. Buys ...
# 6        Agilent Awards Trilogy Sciences with a Golden ...
# ...                                                    ...
# 1848327  Amazon's Offline Retail Store Plan to Boost Ge...
# 1848328  Nordstrom (JWN) Up 25% in 6 Months: Will the R...
# 1848329  Here's Why Abercrombie Offers a Balanced Risk-...
# 1848330  Zumiez (ZUMZ) Up 10.7% Since Last Earnings Rep...
# 1848331  Is Zumiez (ZUMZ) Outperforming Other Retail-Wh...
#
#                                                        url  publisher  \
# 2        http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus
# 3        http://www.zacks.com/stock/news/931205/agilent...      Zacks
# ...

# %%
type(data2['date'])
# Out:
# pandas.core.series.Series

# %%
data2['date'] =pd.to_datetime(data2.date)
data2.sort_values(by=['date'])
# Out:
# C:\Users\Giulia\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                   headline  \
# 1848331  Is Zumiez (ZUMZ) Outperforming Other Retail-Wh...
# 1806388            Ending 2019 And Beginning 2020 Overview
# 971781   Is Lithia Motors (LAD) Stock Undervalued Right...
# 1438112  Earnings Preview: Schnitzer Steel (SCHN) Q1 Ea...
# 1623141  Contrarian Investing in Europe, Japan & Commod...
# ...                                                    ...
# 738604   Aviva Italy Chooses Guidewire InsuranceSuite C...
# 1144133  5 High-Flying Corporate Behemoths With More Up...
# ...

# %%
data2=data2.drop(['url'], axis=1)

# %%
data2.head()
# Out:
#                                             headline  publisher       date  \
# 2  Agilent Technologies Announces Pricing of $5……...  GuruFocus 2020-06-01
# 3  Agilent (A) Gears Up for Q2 Earnings: What's i...      Zacks 2020-05-18
# 4  J.P. Morgan Asset Management Announces Liquida...  GuruFocus 2020-05-15
# 5  Pershing Square Capital Management, L.P. Buys ...  GuruFocus 2020-05-15
# 6  Agilent Awards Trilogy Sciences with a Golden ...  GuruFocus 2020-05-12
#
#   stock
# 2     A
# 3     A
# 4     A
# 5     A
# 6     A

# %%
data2.describe()
# Out:
# C:\Users\Giulia\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#                                                  headline  publisher  \
# count                                               96343      96343
# unique                                              51520          5
# top     Saba Capital Management, L.P. Buys Voya Prime ...  GuruFocus
# freq                                                   83      51212
# first                                                 NaN        NaN
# last                                                  NaN        NaN
#
#                        date  stock
# count                 96343  96343
# unique                  156   3927
# ...

# %%
data2.to_csv('data2020_more.csv',index=False)

# %%
data2.describe()
# Out:
# C:\Users\Giulia\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#                                                  headline  publisher  \
# count                                               96343      96343
# unique                                              51520          5
# top     Saba Capital Management, L.P. Buys Voya Prime ...  GuruFocus
# freq                                                   83      51212
# first                                                 NaN        NaN
# last                                                  NaN        NaN
#
#                        date  stock
# count                 96343  96343
# unique                  156   3927
# ...

# %%
data2.publisher.unique()
# Out:
# array(['GuruFocus', 'Zacks', "Investor's Business Daily", 'TalkMarkets',
#        'BayStreet'], dtype=object)

# %% [markdown]
# # THIRD DATASET from
# https://www.kaggle.com/matthewkoen/news-headlines-with-relevant-stock-tickers containing data from july to end august 2020

# %%
d3 = pd.read_csv('kaggle.csv')
d3
# Out:
#                  Time/Date              Tickers  \
# 0      2020-08-28 04:46:00               $CYDY
# 1      2020-08-28 04:41:00  $AAPL $AAPL $TCEHY
# 2      2020-08-28 04:38:00                $CCH
# 3      2020-08-28 04:38:00               $LEGN
# 4      2020-08-28 04:37:00               $EDEN
# ...                    ...                  ...
# 14083  2020-07-09 08:45:00               $CCXI
# 14084  2020-07-09 08:45:00   $KLAC $KLAC $AMAT
# 14085  2020-07-09 08:41:00               $CDXC
# 14086  2020-07-09 08:40:00       $SDVKY $SDVKF
# 14087  2020-07-09 08:38:00                 $OR
#
#                                                                                   Headlines
# 0            CytoDyn to update investors on regulatory and clinical activities September 2
# 1                                           Apple terminates Epic Games' developer account
# 2                  Utz Quality Foods and Collier Creek Holdings combine to form Utz Brands
# ...

# %%
d3['stock']=d3['Tickers']
d3=d3.drop(['Tickers'],axis=1)

# %%
d3['date'] =pd.to_datetime(d3['date'])
d3['date']=d3['date'].dt.date
d3
# Out:
#                                                                                   Headlines  \
# 0            CytoDyn to update investors on regulatory and clinical activities September 2
# 1                                           Apple terminates Epic Games' developer account
# 2                  Utz Quality Foods and Collier Creek Holdings combine to form Utz Brands
# 3                                    Legend Biotech EPS misses by $0.42, misses on revenue
# 4            Denmark's AAA rating affirmed by S&P as fiscal headroom to absorb COVID shock
# ...                                                                                     ...
# 14083           ChemoCentryx files U.S. avacopan application for blood vessel inflammation
# 14084                                  KLA downgraded as valuation limits upside potential
# 14085   ChromaDex reports promising anti-viral effects of Niagen in coronavirus cell model
# ...

# %%
d3['headline']=d3['Headlines']
d3=d3.drop(['Headlines'],axis=1)
d3
# Out:
#              date                stock  \
# 0      2020-08-28               $CYDY
# 1      2020-08-28  $AAPL $AAPL $TCEHY
# 2      2020-08-28                $CCH
# 3      2020-08-28               $LEGN
# 4      2020-08-28               $EDEN
# ...           ...                  ...
# 14083  2020-07-09               $CCXI
# 14084  2020-07-09   $KLAC $KLAC $AMAT
# 14085  2020-07-09               $CDXC
# 14086  2020-07-09       $SDVKY $SDVKF
# 14087  2020-07-09                 $OR
#
#                                                                                    headline
# 0            CytoDyn to update investors on regulatory and clinical activities September 2
# 1                                           Apple terminates Epic Games' developer account
# 2                  Utz Quality Foods and Collier Creek Holdings combine to form Utz Brands
# 3                                    Legend Biotech EPS misses by $0.42, misses on revenue
# ...

# %%
d3 = d3.reindex(columns=['date','headline','stock'])
d3
# Out:
#              date  \
# 0      2020-08-28
# 1      2020-08-28
# 2      2020-08-28
# 3      2020-08-28
# 4      2020-08-28
# ...           ...
# 14083  2020-07-09
# 14084  2020-07-09
# 14085  2020-07-09
# 14086  2020-07-09
# 14087  2020-07-09
#
#                                                                                    headline  \
# 0            CytoDyn to update investors on regulatory and clinical activities September 2
# 1                                           Apple terminates Epic Games' developer account
# 2                  Utz Quality Foods and Collier Creek Holdings combine to form Utz Brands
# 3                                    Legend Biotech EPS misses by $0.42, misses on revenue
# 4            Denmark's AAA rating affirmed by S&P as fiscal headroom to absorb COVID shock
# ...                                                                                     ...
# 14083           ChemoCentryx files U.S. avacopan application for blood vessel inflammation
# ...

# %%
d3.to_csv('kaggle.csv', index=False)

# %%
d3
# Out:
#              date  \
# 0      2020-08-28
# 1      2020-08-28
# 2      2020-08-28
# 3      2020-08-28
# 4      2020-08-28
# ...           ...
# 14083  2020-07-09
# 14084  2020-07-09
# 14085  2020-07-09
# 14086  2020-07-09
# 14087  2020-07-09
#
#                                                                                    headline  \
# 0            CytoDyn to update investors on regulatory and clinical activities September 2
# 1                                           Apple terminates Epic Games' developer account
# 2                  Utz Quality Foods and Collier Creek Holdings combine to form Utz Brands
# 3                                    Legend Biotech EPS misses by $0.42, misses on revenue
# 4            Denmark's AAA rating affirmed by S&P as fiscal headroom to absorb COVID shock
# ...                                                                                     ...
# 14083           ChemoCentryx files U.S. avacopan application for blood vessel inflammation
# ...

# %% [markdown]
# # Data cleaning FIRST DATASET

# %%
import pandas as pd

# %%
d1=pd.read_csv('data2020.csv')
d1.head()
# Out:
#    Unnamed: 0        Date  \
# 0           0  2020-07-17
# 1           1  2020-07-17
# 2           2  2020-07-17
# 3           3  2020-07-17
# 4           4  2020-07-16
#
#                                                                                                                                                                                                                          headline
# 0                                                     Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# 1                                     Cramer's lightning round: I would own Teradyne. "Mad Money" host Jim Cramer rings the lightning round bell, which means he's giving his answers to callers' stock questions at rapid speed.
# ...

# %%
pd.set_option('display.max_colwidth',None)
# Out:
# 0                                                                                                                                                                  Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# 1                                                                                                                                                  Cramer's lightning round: I would own Teradyne. "Mad Money" host Jim Cramer rings the lightning round bell, which means he's giving his answers to callers' stock questions at rapid speed.
# ...

# %%
d1=d1.drop(['Description'], axis=1)
d1=d1.drop(['Headlines'], axis=1)
d1
# Out:
#              Date  \
# 0      2020-07-17
# 1      2020-07-17
# 2      2020-07-17
# 3      2020-07-17
# 4      2020-07-16
# ...           ...
# 13862  2020-01-01
# 13863  2020-01-01
# 13864  2020-01-01
# 13865  2020-01-01
# 13866  2020-01-01
#
#                                                                                                                                                                                                                                                                                                                                     headline
# 0                                                                                                                                                                Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# ...

# %%
d1.to_csv('data2020.csv', index=False)

# %%
import regex

# %%
d1=pd.read_csv('data2020.csv')
d1.drop(d1.filter(regex='Unnamed:'),axis=1, inplace=True)

# %%
d1
# Out:
#              Date  \
# 0      2020-07-17
# 1      2020-07-17
# 2      2020-07-17
# 3      2020-07-17
# 4      2020-07-16
# ...           ...
# 13862  2020-01-01
# 13863  2020-01-01
# 13864  2020-01-01
# 13865  2020-01-01
# 13866  2020-01-01
#
#                                                                                                                                                                                                                                                                                                                                     headline
# 0                                                                                                                                                                Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# ...

# %%
d1.to_csv('data2020.csv', index=False)

# %%
d1=pd.read_csv('data2020.csv')
d1
# Out:
#              Date  \
# 0      2020-07-17
# 1      2020-07-17
# 2      2020-07-17
# 3      2020-07-17
# 4      2020-07-16
# ...           ...
# 13862  2020-01-01
# 13863  2020-01-01
# 13864  2020-01-01
# 13865  2020-01-01
# 13866  2020-01-01
#
#                                                                                                                                                                                                                                                                                                                                     headline
# 0                                                                                                                                                                Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# ...

# %%
d1['date']= d1['Date']
d1=d1.drop(['Date'],axis=1)
d1
# Out:
#                                                                                                                                                                                                                                                                                                                                     headline  \
# 0                                                                                                                                                                Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# ...

# %%
d1['stock']="NA"
d1 = d1.reindex(columns=['date','headline','stock'])
d1
# Out:
#              date  \
# 0      2020-07-17
# 1      2020-07-17
# 2      2020-07-17
# 3      2020-07-17
# 4      2020-07-16
# ...           ...
# 13862  2020-01-01
# 13863  2020-01-01
# 13864  2020-01-01
# 13865  2020-01-01
# 13866  2020-01-01
#
#                                                                                                                                                                                                                                                                                                                                     headline  \
# 0                                                                                                                                                                Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# ...

# %%
d1.to_csv('data2020.csv', index=False)

# %% [markdown]
# # Data cleaning SECOND DATASET

# %%
d2 = pd.read_csv('data2020_more.csv')
d2
# Out:
#                                                                                                   headline  \
# 0                                   Agilent Technologies Announces Pricing of $5…… Million of Senior Notes
# 1                                               Agilent (A) Gears Up for Q2 Earnings: What's in the Cards?
# 2                          J.P. Morgan Asset Management Announces Liquidation of Six Exchange-Traded Funds
# 3      Pershing Square Capital Management, L.P. Buys Agilent Technologies Inc, The Howard Hughes Corp, ...
# 4                                       Agilent Awards Trilogy Sciences with a Golden Ticket at LabCentral
# ...                                                                                                    ...
# 96338                                         Amazon's Offline Retail Store Plan to Boost Germany Presence
# 96339                                         Nordstrom (JWN) Up 25% in 6 Months: Will the Rally Continue?
# ...

# %%
d2=d2.drop(['publisher'],axis=1)
d2
# Out:
#                                                                                                   headline  \
# 0                                   Agilent Technologies Announces Pricing of $5…… Million of Senior Notes
# 1                                               Agilent (A) Gears Up for Q2 Earnings: What's in the Cards?
# 2                          J.P. Morgan Asset Management Announces Liquidation of Six Exchange-Traded Funds
# 3      Pershing Square Capital Management, L.P. Buys Agilent Technologies Inc, The Howard Hughes Corp, ...
# 4                                       Agilent Awards Trilogy Sciences with a Golden Ticket at LabCentral
# ...                                                                                                    ...
# 96338                                         Amazon's Offline Retail Store Plan to Boost Germany Presence
# 96339                                         Nordstrom (JWN) Up 25% in 6 Months: Will the Rally Continue?
# ...

# %%
#controllo se ci sono stock ticker uguali a 'NA'
p2=d2[d2['stock']=='NA']
p2
# Out:
# Empty DataFrame
# Columns: [headline, date, stock]
# Index: []

# %%
d2 = d2.reindex(columns=['date','headline','stock'])
d2
# Out:
#              date  \
# 0      2020-06-01
# 1      2020-05-18
# 2      2020-05-15
# 3      2020-05-15
# 4      2020-05-12
# ...           ...
# 96338  2020-01-07
# 96339  2020-01-06
# 96340  2020-01-06
# 96341  2020-01-04
# 96342  2020-01-01
#
#                                                                                                   headline  \
# 0                                   Agilent Technologies Announces Pricing of $5…… Million of Senior Notes
# 1                                               Agilent (A) Gears Up for Q2 Earnings: What's in the Cards?
# 2                          J.P. Morgan Asset Management Announces Liquidation of Six Exchange-Traded Funds
# 3      Pershing Square Capital Management, L.P. Buys Agilent Technologies Inc, The Howard Hughes Corp, ...
# 4                                       Agilent Awards Trilogy Sciences with a Golden Ticket at LabCentral
# ...

# %%
d2.to_csv('data2020_more.csv', index=False)

# %% [markdown]
# # Data cleaning THIRD DATASET

# %%
d3=pd.read_csv('kaggle.csv')
d3
# Out:
#              date  \
# 0      2020-08-28
# 1      2020-08-28
# 2      2020-08-28
# 3      2020-08-28
# 4      2020-08-28
# ...           ...
# 14083  2020-07-09
# 14084  2020-07-09
# 14085  2020-07-09
# 14086  2020-07-09
# 14087  2020-07-09
#
#                                                                                    headline  \
# 0            CytoDyn to update investors on regulatory and clinical activities September 2
# 1                                           Apple terminates Epic Games' developer account
# 2                  Utz Quality Foods and Collier Creek Holdings combine to form Utz Brands
# 3                                    Legend Biotech EPS misses by $0.42, misses on revenue
# 4            Denmark's AAA rating affirmed by S&P as fiscal headroom to absorb COVID shock
# ...                                                                                     ...
# 14083           ChemoCentryx files U.S. avacopan application for blood vessel inflammation
# ...

# %% [markdown]
# # MERGE ALL THREE CLEANED DATASETS

# %%
d1
# Out:
#              date  \
# 0      2020-07-17
# 1      2020-07-17
# 2      2020-07-17
# 3      2020-07-17
# 4      2020-07-16
# ...           ...
# 13862  2020-01-01
# 13863  2020-01-01
# 13864  2020-01-01
# 13865  2020-01-01
# 13866  2020-01-01
#
#                                                                                                                                                                                                                                                                                                                                     headline  \
# 0                                                                                                                                                                Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# ...

# %%
d2
# Out:
#              date  \
# 0      2020-06-01
# 1      2020-05-18
# 2      2020-05-15
# 3      2020-05-15
# 4      2020-05-12
# ...           ...
# 96338  2020-01-07
# 96339  2020-01-06
# 96340  2020-01-06
# 96341  2020-01-04
# 96342  2020-01-01
#
#                                                                                                   headline  \
# 0                                   Agilent Technologies Announces Pricing of $5…… Million of Senior Notes
# 1                                               Agilent (A) Gears Up for Q2 Earnings: What's in the Cards?
# 2                          J.P. Morgan Asset Management Announces Liquidation of Six Exchange-Traded Funds
# 3      Pershing Square Capital Management, L.P. Buys Agilent Technologies Inc, The Howard Hughes Corp, ...
# 4                                       Agilent Awards Trilogy Sciences with a Golden Ticket at LabCentral
# ...

# %%
d3
# Out:
#              date  \
# 0      2020-08-28
# 1      2020-08-28
# 2      2020-08-28
# 3      2020-08-28
# 4      2020-08-28
# ...           ...
# 14083  2020-07-09
# 14084  2020-07-09
# 14085  2020-07-09
# 14086  2020-07-09
# 14087  2020-07-09
#
#                                                                                    headline  \
# 0            CytoDyn to update investors on regulatory and clinical activities September 2
# 1                                           Apple terminates Epic Games' developer account
# 2                  Utz Quality Foods and Collier Creek Holdings combine to form Utz Brands
# 3                                    Legend Biotech EPS misses by $0.42, misses on revenue
# 4            Denmark's AAA rating affirmed by S&P as fiscal headroom to absorb COVID shock
# ...                                                                                     ...
# 14083           ChemoCentryx files U.S. avacopan application for blood vessel inflammation
# ...

# %%
list_of_df = []
list_of_df.append(d1)
list_of_df.append(d2)
list_of_df.append(d3)
merged_df = pd.concat(list_of_df)
merged_df
# Out:
#              date  \
# 0      2020-07-17
# 1      2020-07-17
# 2      2020-07-17
# 3      2020-07-17
# 4      2020-07-16
# ...           ...
# 14083  2020-07-09
# 14084  2020-07-09
# 14085  2020-07-09
# 14086  2020-07-09
# 14087  2020-07-09
#
#                                                                                                                                                                                                                              headline  \
# 0                                                         Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# 1                                         Cramer's lightning round: I would own Teradyne. "Mad Money" host Jim Cramer rings the lightning round bell, which means he's giving his answers to callers' stock questions at rapid speed.
# ...

# %%
merged_df.to_csv('TUTTE_NEWS.csv',index=False)

# %%
merged_df
# Out:
#              date  \
# 0      2020-07-17
# 1      2020-07-17
# 2      2020-07-17
# 3      2020-07-17
# 4      2020-07-16
# ...           ...
# 14083  2020-07-09
# 14084  2020-07-09
# 14085  2020-07-09
# 14086  2020-07-09
# 14087  2020-07-09
#
#                                                                                                                                                                                                                              headline  \
# 0                                                         Jim Cramer: A better way to invest in the Covid-19 vaccine gold rush. "Mad Money" host Jim Cramer recommended buying four companies that are supporting vaccine developers.
# 1                                         Cramer's lightning round: I would own Teradyne. "Mad Money" host Jim Cramer rings the lightning round bell, which means he's giving his answers to callers' stock questions at rapid speed.
# ...
